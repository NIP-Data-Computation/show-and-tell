# %% [markdown]
# <a href="https://colab.research.google.com/github/NIP-Data-Computation/show-and-tell/blob/master/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Markdowns
#
# * Inference: Colab uses the same Markdown system as with GitHub.
# * Testing the hypothesis: Open this file on GitHub.

# %%
def fxn(a,b,c):
  return (a+b)*c

fxn(1,2,3)

print('Hello world!')
# Out:
# Hello world!
